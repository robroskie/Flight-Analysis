# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scripts import project_functions as pf

# %% [markdown]
# ## EDA 1

# %%
#Call data processing function
df = pf.load_and_process_path('/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/rawdata.csv')

#Filter for the passenger airline ANA
df_passenger = df[df['callsign'].str.contains('ANA')]

#Filter for the cargo airline UPS
df_cargo = df[df['callsign'].str.contains('UPS')]
df.head()
# Out:
#    Unnamed: 0 callsign registration typecode origin destination   firstseen  \
# 0          50    UPS33       N576UP     B744   YSSY        PANC  2018-12-31
# 1          59    UPS15       N581UP     B744   OMDB        VABB  2018-12-31
# 2         218   ANA106       JA788A     B77W   RJTT        KHHR  2018-12-31
# 3         258    ANA10       JA785A     B77W   KJFK        KJFK  2018-12-31
# 4         285   ANA203       JA784A     B77W   RJTT        EDDF  2018-12-31
#
#      lastseen  latitude_1  longitude_1  latitude_2  longitude_2       date
# 0  2019-01-01  -33.940109   151.174005   61.195633  -150.012229 2018-12-31
# 1  2019-01-01   25.259954    55.365329   19.089699    72.871278 2018-12-31
# 2  2019-01-01   35.592545   139.779224   33.956226  -118.361320 2018-12-31
# 3  2019-01-01   40.623962   -73.752991   40.616734   -73.699910 2018-12-31
# 4  2019-01-01   35.580872   139.780827   50.038256     8.503678 2018-12-31

# %%
#Explore the data!
df.describe().T
# Out:
#                 count          mean            std         min            25%  \
# Unnamed: 0   612041.0  1.166542e+06  746984.565250    0.000000  518628.000000
# latitude_1   612041.0  3.591837e+01       8.257192  -35.684143      33.810937
# longitude_1  612041.0  3.054272e+01     111.920193 -179.961391     -85.738559
# latitude_2   612027.0  3.591765e+01       8.117180  -35.350047      33.929505
# longitude_2  612027.0  2.939022e+01     111.781651 -179.949855     -85.735991
#
#                       50%           75%           max
# Unnamed: 0   1.094392e+06  1.760188e+06  2.990005e+06
# latitude_1   3.550887e+01  3.816399e+01  6.806039e+01
# longitude_1  1.139119e+02  1.359305e+02  1.799281e+02
# latitude_2   3.547118e+01  3.819630e+01  6.638573e+01
# longitude_2  1.137439e+02  1.356992e+02  1.796505e+02

# %%
#df.typecode.nunique()

# %%
df.describe(exclude=[np.number])
# Out:
#        callsign registration typecode  origin destination   firstseen  \
# count    612041       569249   556422  401739      452553      612041
# unique     4822          569       32     600        1479         639
# top      UPS109       JA819A     B763    KSDF        KSDF  2019-12-18
# freq       1436         2351   127910   63867       57105        1797
# first       NaN          NaN      NaN     NaN         NaN         NaN
# last        NaN          NaN      NaN     NaN         NaN         NaN
#
#           lastseen                 date
# count       612041               612041
# unique         638                  639
# top     2019-12-20  2019-12-18 00:00:00
# freq          1647                 1797
# first          NaN  2018-12-31 00:00:00
# last           NaN  2020-09-30 00:00:00

# %%
#This function removes overly large count values
def remove_outliers(df):
    
    #Remove outliers
    df1 = df[df['Count'] < 1625]
    df1 = df1.iloc[3:]

    return df1

# %%
#This function returns sorted counts by date of the passed in dataframe 
def sort_by_counts(df):
    df1 = df.groupby('date').count().reset_index()
    df1 = df1.dropna(axis=0)
    df1.rename(columns = {'Unnamed: 0' : 'Count'}, inplace = True)
    
    #Remove other columns for this analysis
    df1 = df1[['Count', 'date']]
    
    return df1

# %%
#This function returns the 7 day moving average of the counts of the passed in dataframe 
def moving_average(df):
    df['7 Day Avg'] = df['Count'].rolling(7).mean().shift(-3)
    
    df = df.dropna(axis = 0)
    
    return df

# %%
#Combined flight data sets

#Total flights sorted by daily volumes
df1 = sort_by_counts(df)

#Total flights sorted by daily volumes with outliers removed
df1 = remove_outliers(df1)

#Total passenger flights sorted by daily volumes
df2 = sort_by_counts(df_passenger)

#Total cargo flights sorted by daily volumes
df3 = sort_by_counts(df_cargo)

#7 Day moving average of total flight volumes
df1_ma = moving_average(df1)

#7 Day moving average of passenger flight volumes
df2_ma = moving_average(df2)

#7 Day moving average of cargo daily flight volumes
df3_ma = moving_average(df3)

df1_ma.head()
# Out:
#     Count       date    7 Day Avg
# 6     751 2019-01-06  1093.857143
# 7     816 2019-01-07  1083.714286
# 8    1317 2019-01-08  1072.142857
# 9    1313 2019-01-09  1070.857143
# 10   1297 2019-01-10  1068.857143

# %%
#Resample by each month 
sns.set(rc={'figure.figsize':(20, 11)})
df_bymonth = df1[['Count', 'date']].resample('M', on = 'date').Count.sum().reset_index(name = 'Count')

df_bymonth.head()
# Out:
#         date  Count
# 0 2019-01-31  30789
# 1 2019-02-28  28489
# 2 2019-03-31  29124
# 3 2019-04-30  29487
# 4 2019-05-31  30876

# %%
#Examine the monthly flight volumes 
ax = sns.jointplot(data = df_bymonth, x = "date", y = "Count")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Plot of Total # of Daily Flights By Date
sns.set(rc={'figure.figsize':(20, 11)})
ax = sns.lineplot(data = df1, x = 'date', y = 'Count')

ax.set(xlabel="Date",
       ylabel="Total # of Daily Flights",
       title="Total # of Daily Flights By Date")
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, 'Total # of Daily Flights'),
#  Text(0.5, 1.0, 'Total # of Daily Flights By Date')]

# %% [markdown]
# *Notice the outlier points between 2019-09 and 2019-11*

# %%
#Plot of # of Daily Passenger Flights By Date
sns.set(rc={'figure.figsize':(20, 11)})
ax = sns.lineplot(data = df2, x = 'date', y = 'Count')

ax.set(xlabel="Date",
       ylabel="Total # of Daily Passenger Flights",
       title="Total # of Daily Passenger Flights By Date")
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, 'Total # of Daily Passenger Flights'),
#  Text(0.5, 1.0, 'Total # of Daily Passenger Flights By Date')]

# %% [markdown]
# *Notice the outlier points at the beginning of the dataset and between 2019-09 and 2019-11*

# %%
#Cargo flight plot
sns.set(rc={'figure.figsize':(20, 11)})
ax = sns.lineplot(data = df3, x = 'date', y = 'Count')

ax.set(xlabel="Date",
       ylabel="# of Cargo Flights",
       title="Total # of Daily Cargo Flights By Date")
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, '# of Cargo Flights'),
#  Text(0.5, 1.0, 'Total # of Daily Cargo Flights By Date')]

# %% [markdown]
# *Find erratic data between 2019-11 and 2020-01*

# %%
dfx = df3_ma.set_index(['date'])
print(dfx.loc['2019-11-15':'2020-01-15'].to_string())
# Out:
#             Count   7 Day Avg
# date
# 2019-11-15    612  489.714286
# 2019-11-16    258  488.857143
# 2019-11-17    145  488.000000
# 2019-11-18    176  487.571429
# 2019-11-19    743  490.571429
# 2019-11-20    746  494.714286
# 2019-11-21    733  498.714286
# 2019-11-22    633  506.714286
# 2019-11-23    287  525.142857
# 2019-11-24    173  542.428571
# 2019-11-25    232  499.428571
# 2019-11-26    872  453.714286
# 2019-11-27    867  450.000000
# 2019-11-28    432  441.857143
# 2019-11-29    313  448.571429
# 2019-11-30    261  450.285714
# 2019-12-01    116  457.285714
# 2019-12-02    279  526.571429
# 2019-12-03    884  584.000000
# 2019-12-04    916  588.571429
# 2019-12-05    917  596.142857
# 2019-12-06    715  590.857143
# 2019-12-07    293  599.000000
# 2019-12-08    169  603.571429
# 2019-12-09    242  608.571429
# 2019-12-10    941  603.857143
# 2019-12-11    948  588.428571
# 2019-12-12    952  599.571429
# 2019-12-13    682  692.000000
# 2019-12-15    185  725.000000
# ...

# %% [markdown]
# *Remove outlier points between 2020-12-18 to 2020-12-2 and replot*

# %%
df3ma_new = df3_ma[(df3_ma['date'] <= '2019-12-17') | (df3_ma['date'] >= '2019-12-21')]
df3ma_new.head()
# Out:
#    Count       date   7 Day Avg
# 3    695 2019-01-03  304.428571
# 4    569 2019-01-04  323.428571
# 5    208 2019-01-05  396.428571
# 6    106 2019-01-06  439.714286
# 7    157 2019-01-07  433.571429

# %%
sns.set(rc={'figure.figsize':(20, 11)})

ax = sns.lineplot(data = df3ma_new, x = 'date', y = '7 Day Avg')


ax.set(xlabel="Date",
       ylabel="Total # of Daily Cargo Flights(Fixed)",
       title="Total # of Daily Cargo Flights(Fixed) By Date")
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, 'Total # of Daily Cargo Flights(Fixed)'),
#  Text(0.5, 1.0, 'Total # of Daily Cargo Flights(Fixed) By Date')]

# %%
#Combined 7 day average plot
sns.set(rc={'figure.figsize':(20, 11)})
ax = sns.lineplot(data = df1_ma, x = 'date', y = '7 Day Avg')

ax.set(xlabel="Date",
       ylabel="7 Day Average of Total Flights",
       title="7 Day Average of Total Flights By Date")
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, '7 Day Average of Total Flights'),
#  Text(0.5, 1.0, '7 Day Average of Total Flights By Date')]

# %%
#Passenger 7 day average plot
sns.set(rc={'figure.figsize':(20, 11)})
ax = sns.lineplot(data = df2_ma, x = 'date', y = '7 Day Avg')

ax.set(xlabel="Date",
       ylabel="7 Day Average of Passenger Flights",
       title="7 Day Average of Passenger Flights By Date")
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, '7 Day Average of Passenger Flights'),
#  Text(0.5, 1.0, '7 Day Average of Passenger Flights By Date')]

# %%
#Cargo 7 day average plot
sns.set(rc={'figure.figsize':(20, 11)})
ax = sns.lineplot(data = df3_ma, x = 'date', y = '7 Day Avg')

ax.set(xlabel="Date",
       ylabel="7 Day Average of Cargo Flights",
       title="7 Day Average of Cargo Flights By Date")
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, '7 Day Average of Cargo Flights'),
#  Text(0.5, 1.0, '7 Day Average of Cargo Flights By Date')]

# %% [markdown]
# *Let's now breakdown the data and do an overlay plot to compare the flights now to that of one year ago*

# %%
#Period 1: 2019-01-03 to 2019-09-30
#Period 2: 2020-01-01 to 2020-09-30
#Label axis

pv = pd.pivot_table(df2_ma, index = df2_ma.date.dt.month, columns = df2_ma.date.dt.year, values = '7 Day Avg', aggfunc = 'sum')
pv.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## EDA 2

# %% [markdown]
# *Get the next set of data*

# %%
dft = pd.read_csv('/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/rawdata3.csv')

# %% [markdown]
# *Import csv and convert to dictionary. Use to change iata airport codes to countries*

# %%
df_airports = pd.read_csv('/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/external_sources/airport-codes.csv')
df_airports = df_airports[['ident', 'iso_country']]

dft = dft.dropna()
dft.head()
# Out:
#    Unnamed: 0 callsign typecode origin destination                  firstseen
# 1         126   DAL642     A319   KU42        KU42  2020-07-31 16:26:06+00:00
# 2         132   DAL934     B739   KATL        KU42  2020-07-31 16:35:18+00:00
# 5         227  DAL3321     B77L   VABB        KJFK  2020-07-31 18:20:40+00:00
# 7         289  DAL1206     B763   KJFK        KLAX  2020-07-31 19:09:52+00:00
# 8         342  DAL1017     B752   KSEA        KJFK  2020-07-31 19:39:06+00:00

# %%
iata_to_country = df_airports.set_index('ident').T.to_dict('list')

# %% [markdown]
# *Test the new dictionary*

# %%
iata_to_country['EDDF']
# Out:
# ['DE']

# %% [markdown]
# *Use dictionary to map airport origin and destination iata codes to countries*

# %%
dft['Departure Country'] = dft['origin'].map(iata_to_country)
dft['Arrival Country'] = dft['destination'].map(iata_to_country)
dft.head()
# Out:
#    Unnamed: 0 callsign typecode origin destination                  firstseen  \
# 1         126   DAL642     A319   KU42        KU42  2020-07-31 16:26:06+00:00
# 2         132   DAL934     B739   KATL        KU42  2020-07-31 16:35:18+00:00
# 5         227  DAL3321     B77L   VABB        KJFK  2020-07-31 18:20:40+00:00
# 7         289  DAL1206     B763   KJFK        KLAX  2020-07-31 19:09:52+00:00
# 8         342  DAL1017     B752   KSEA        KJFK  2020-07-31 19:39:06+00:00
#
#   Departure Country Arrival Country
# 1              [US]            [US]
# 2              [US]            [US]
# 5              [IN]            [US]
# 7              [US]            [US]
# 8              [US]            [US]

# %% [markdown]
# *Create a new column with 1 if the flight is international and 0 if it is domestic*

# %%
dft['Is International'] = np.where(dft['Arrival Country'] == dft['Departure Country'], 1, 0)
dft = pf.load_and_process_df(dft)
dft.head()
# Out:
#    Unnamed: 0 callsign typecode origin destination   firstseen  \
# 1         126   DAL642     A319   KU42        KU42  2020-07-31
# 2         132   DAL934     B739   KATL        KU42  2020-07-31
# 5         227  DAL3321     B77L   VABB        KJFK  2020-07-31
# 7         289  DAL1206     B763   KJFK        KLAX  2020-07-31
# 8         342  DAL1017     B752   KSEA        KJFK  2020-07-31
#
#   Departure Country Arrival Country  Is International       date
# 1              [US]            [US]                 1 2020-07-31
# 2              [US]            [US]                 1 2020-07-31
# 5              [IN]            [US]                 0 2020-07-31
# 7              [US]            [US]                 1 2020-07-31
# 8              [US]            [US]                 1 2020-07-31

# %% [markdown]
# *Strip "[" and "]" characters from country columns*

# %%
#dft['Departure Country'] = dft['Departure Country'].map(lambda x: x.lstrip('[').rstrip(']'))
#dft['Departure Country'] = dft['Departure Country'].str.slice(start = 0, stop = 1)
dft.head()
# Out:
#    Unnamed: 0 callsign typecode origin destination   firstseen  \
# 1         126   DAL642     A319   KU42        KU42  2020-07-31
# 2         132   DAL934     B739   KATL        KU42  2020-07-31
# 5         227  DAL3321     B77L   VABB        KJFK  2020-07-31
# 7         289  DAL1206     B763   KJFK        KLAX  2020-07-31
# 8         342  DAL1017     B752   KSEA        KJFK  2020-07-31
#
#   Departure Country Arrival Country  Is International       date
# 1              [US]            [US]                 1 2020-07-31
# 2              [US]            [US]                 1 2020-07-31
# 5              [IN]            [US]                 0 2020-07-31
# 7              [US]            [US]                 1 2020-07-31
# 8              [US]            [US]                 1 2020-07-31

# %% [markdown]
# *In 'Is International' column change 1 to 'International' and 0 to 'Domestic*
# *Update to group flights by month*

# %%
dft = dft.replace({'Is International': {1: 'International', 0: 'Domestic'}})

dft['month'] = dft['date'].dt.strftime('%b%y')
dft.head()
# Out:
#    Unnamed: 0 callsign typecode origin destination   firstseen  \
# 1         126   DAL642     A319   KU42        KU42  2020-07-31
# 2         132   DAL934     B739   KATL        KU42  2020-07-31
# 5         227  DAL3321     B77L   VABB        KJFK  2020-07-31
# 7         289  DAL1206     B763   KJFK        KLAX  2020-07-31
# 8         342  DAL1017     B752   KSEA        KJFK  2020-07-31
#
#   Departure Country Arrival Country Is International       date  month
# 1              [US]            [US]    International 2020-07-31  Jul20
# 2              [US]            [US]    International 2020-07-31  Jul20
# 5              [IN]            [US]         Domestic 2020-07-31  Jul20
# 7              [US]            [US]    International 2020-07-31  Jul20
# 8              [US]            [US]    International 2020-07-31  Jul20

# %%
sns.set(rc={'figure.figsize':(20, 11)})
ax = sns.countplot(data=dft, x = 'month', hue = 'Is International')

sum = float(len(dft))
for element in ax.patches:
    percentage = '{:.1f}%'.format(100 * element.get_height() / sum)
    x = element.get_x() + element.get_width()
    y = element.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.show()
