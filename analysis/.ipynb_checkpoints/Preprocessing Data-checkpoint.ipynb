# %%
import pandas as pd

#import all csv datasets as Pandas dataframes
df19_1 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190101_20190131.csv")
df19_2 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190201_20190228.csv")
df19_3 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190301_20190331.csv")
df19_4 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190401_20190430.csv")
df19_5 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190501_20190531.csv")
df19_6 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190601_20190630.csv")
df19_7 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190701_20190731.csv")
df19_8 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190801_20190831.csv")
df19_9 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190901_20190930.csv")
df19_10 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20191001_20191031.csv")
df19_11 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20191101_20191130.csv")
df19_12 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20191201_20191231.csv")

df20_1 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200101_20200131.csv")
df20_2 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200201_20200229.csv")
df20_3 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200301_20200331.csv")
df20_4 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200401_20200430.csv")
df20_5 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200501_20200531.csv")
df20_6 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200601_20200630.csv")
df20_7 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200701_20200731.csv")
df20_8 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200801_20200831.csv")
df20_9 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200901_20200930.csv")

#Filter each dataset to only include ANA and UPS airlines
df19_1f = df19_1[df19_1['callsign'].str.contains("ANA") | df19_1['callsign'].str.contains('UPS')] 
df19_2f = df19_2[df19_2['callsign'].str.contains("ANA") | df19_2['callsign'].str.contains('UPS')] 
df19_3f = df19_3[df19_3['callsign'].str.contains("ANA") | df19_3['callsign'].str.contains('UPS')] 
df19_4f = df19_4[df19_4['callsign'].str.contains("ANA") | df19_4['callsign'].str.contains('UPS')] 
df19_5f = df19_5[df19_5['callsign'].str.contains("ANA") | df19_5['callsign'].str.contains('UPS')] 
df19_6f = df19_6[df19_6['callsign'].str.contains("ANA") | df19_6['callsign'].str.contains('UPS')]  
df19_7f = df19_7[df19_7['callsign'].str.contains("ANA") | df19_7['callsign'].str.contains('UPS')] 
df19_8f = df19_8[df19_8['callsign'].str.contains("ANA") | df19_8['callsign'].str.contains('UPS')] 
df19_9f = df19_9[df19_9['callsign'].str.contains("ANA") | df19_9['callsign'].str.contains('UPS')] 
df19_10f = df19_10[df19_10['callsign'].str.contains("ANA") | df19_10['callsign'].str.contains('UPS')] 
df19_11f = df19_11[df19_11['callsign'].str.contains("ANA") | df19_11['callsign'].str.contains('UPS')]  
df19_12f = df19_12[df19_12['callsign'].str.contains("ANA") | df19_12['callsign'].str.contains('UPS')] 

df20_1f = df20_1[df20_1['callsign'].str.contains("ANA") | df20_1['callsign'].str.contains('UPS')] 
df20_2f = df20_2[df20_2['callsign'].str.contains("ANA") | df20_2['callsign'].str.contains('UPS')] 
df20_3f = df20_3[df20_3['callsign'].str.contains("ANA") | df20_3['callsign'].str.contains('UPS')] 
df20_4f = df20_4[df20_4['callsign'].str.contains("ANA") | df20_4['callsign'].str.contains('UPS')]  
df20_5f = df20_5[df20_5['callsign'].str.contains("ANA") | df20_5['callsign'].str.contains('UPS')]  
df20_6f = df20_6[df20_6['callsign'].str.contains("ANA") | df20_6['callsign'].str.contains('UPS')] 
df20_7f = df20_7[df20_7['callsign'].str.contains("ANA") | df20_7['callsign'].str.contains('UPS')]  
df20_8f = df20_8[df20_8['callsign'].str.contains("ANA") | df20_8['callsign'].str.contains('UPS')] 
df20_9f = df20_9[df20_9['callsign'].str.contains("ANA") | df20_9['callsign'].str.contains('UPS')] 

#Concatenate the filtered dataframes into a single dataframe
df_19 = pd.concat([df19_1f, df19_2f, df19_3f, df19_4f, df19_5f, df19_6f, df19_7f, df19_8f, df19_9f, df19_10f, df19_11f, df19_12f])
df_20 = pd.concat([df20_1f, df20_2f, df20_3f, df20_4f, df20_5f, df20_6f, df20_7f, df20_8f, df20_9f])
pd_complete = pd.concat([df_19, df_20])
#print(pd_complete)
# Out:
# /Users/luke/opt/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6d22343ee601> in <module>
#      26
#      27 #Filter each dataset to only include ANA and UPS airlines
# ---> 28 df19_1f = df19_1[df19_1['callsign'].str.contains("ANA") | df19_1['callsign'].str.contains('UPS') | df19_1['callsign'].str.contains("DAL") | df19_1['callsign'].str.contains('DHK')]
#      29 df19_2f = df19_2[df19_2['callsign'].str.contains("ANA") | df19_2['callsign'].str.contains('UPS') | df19_2['callsign'].str.contains("DAL") | df19_2['callsign'].str.contains('DHK')]
#      30 df19_3f = df19_3[df19_3['callsign'].str.contains("ANA") | df19_3['callsign'].str.contains('UPS') | df19_3['callsign'].str.contains("DAL") | df19_3['callsign'].str.contains('DHK')]
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/strings.py in wrapper(self, *args, **kwargs)
#    1952                 )
#    1953                 raise TypeError(msg)
# -> 1954             return func(self, *args, **kwargs)
#    1955
#    1956         wrapper.__name__ = func_name
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/strings.py in contains(self, pat, case, flags, na, regex)
#    2760     @forbid_nonstring_types(["bytes"])
#    2761     def contains(self, pat, case=True, flags=0, na=np.nan, regex=True):
# -> 2762         result = str_contains(
#    2763             self._parent, pat, case=case, flags=flags, na=na, regex=regex
#    2764         )
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/strings.py in str_contains(arr, pat, case, flags, na, regex)
#     458             uppered = _na_map(lambda x: x.upper(), arr)
#     459             return _na_map(f, uppered, na, dtype=bool)
# --> 460     return _na_map(f, arr, na, dtype=bool)
#     461
#     462
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/strings.py in _na_map(f, arr, na_result, dtype)
#     129     if na_result is None:
#     130         na_result = np.nan
# --> 131     return _map_object(f, arr, na_mask=True, na_value=na_result, dtype=dtype)
#     132
#     133
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/strings.py in _map_object(f, arr, na_mask, na_value, dtype)
#     214         convert = not np.all(mask)
#     215         try:
# --> 216             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), convert)
#     217         except (TypeError, AttributeError) as e:
#     218             # Reraise the exception if callable `f` got wrong number of args.
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer_mask()
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/strings.py in <lambda>(x)
#     449             )
#     450
# --> 451         f = lambda x: bool(regex.search(x))
#     452     else:
#     453         if case:
#
# KeyboardInterrupt:

# %%
#Filter irrelevant the concatenated dataframe to reduce file size and save as csv file
pd_complete_filt = pd_complete.drop(['lastseen','altitude_1','altitude_2','day','number','icao24'],axis=1)
#print(pd_complete_filt)
pd_complete_filt.to_csv('/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/rawdata1.csv')

# %%
#import all csv datasets as Pandas dataframes
df19_1 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190101_20190131.csv")
df19_2 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190201_20190228.csv")
df19_3 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190301_20190331.csv")
df19_4 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190401_20190430.csv")
df19_5 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190501_20190531.csv")
df19_6 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190601_20190630.csv")
df19_7 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190701_20190731.csv")
df19_8 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190801_20190831.csv")
df19_9 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20190901_20190930.csv")
df19_10 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20191001_20191031.csv")
df19_11 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20191101_20191130.csv")
df19_12 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20191201_20191231.csv")

df20_1 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200101_20200131.csv")
df20_2 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200201_20200229.csv")
df20_3 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200301_20200331.csv")
df20_4 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200401_20200430.csv")
df20_5 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200501_20200531.csv")
df20_6 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200601_20200630.csv")
df20_7 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200701_20200731.csv")
df20_8 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200801_20200831.csv")
df20_9 = pd.read_csv(r"/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data/flightlist_20200901_20200930.csv")

#Filter each dataset to only include ANA and UPS airlines
df19_1f = df19_1[df19_1['callsign'].str.contains("DAL") | df19_1['callsign'].str.contains('QTR')] 
df19_2f = df19_2[df19_2['callsign'].str.contains("DAL") | df19_2['callsign'].str.contains('QTR')] 
df19_3f = df19_3[df19_3['callsign'].str.contains("DAL") | df19_3['callsign'].str.contains('QTR')] 
df19_4f = df19_4[df19_4['callsign'].str.contains("DAL") | df19_4['callsign'].str.contains('QTR')] 
df19_5f = df19_5[df19_5['callsign'].str.contains("DAL") | df19_5['callsign'].str.contains('QTR')] 
df19_6f = df19_6[df19_6['callsign'].str.contains("DAL") | df19_6['callsign'].str.contains('QTR')]  
df19_7f = df19_7[df19_7['callsign'].str.contains("DAL") | df19_7['callsign'].str.contains('QTR')] 
df19_8f = df19_8[df19_8['callsign'].str.contains("DAL") | df19_8['callsign'].str.contains('QTR')] 
df19_9f = df19_9[df19_9['callsign'].str.contains("ANA") | df19_9['callsign'].str.contains('QTR')] 
df19_10f = df19_10[df19_10['callsign'].str.contains("DAL") | df19_10['callsign'].str.contains('QTR')] 
df19_11f = df19_11[df19_11['callsign'].str.contains("DAL") | df19_11['callsign'].str.contains('QTR')]  
df19_12f = df19_12[df19_12['callsign'].str.contains("DAL") | df19_12['callsign'].str.contains('QTR')] 

df20_1f = df20_1[df20_1['callsign'].str.contains("DAL") | df20_1['callsign'].str.contains('QTR')] 
df20_2f = df20_2[df20_2['callsign'].str.contains("DAL") | df20_2['callsign'].str.contains('QTR')] 
df20_3f = df20_3[df20_3['callsign'].str.contains("DAL") | df20_3['callsign'].str.contains('QTR')] 
df20_4f = df20_4[df20_4['callsign'].str.contains("DAL") | df20_4['callsign'].str.contains('QTR')]  
df20_5f = df20_5[df20_5['callsign'].str.contains("DAL") | df20_5['callsign'].str.contains('QTR')]  
df20_6f = df20_6[df20_6['callsign'].str.contains("DAL") | df20_6['callsign'].str.contains('QTR')] 
df20_7f = df20_7[df20_7['callsign'].str.contains("DAL") | df20_7['callsign'].str.contains('QTR')]  
df20_8f = df20_8[df20_8['callsign'].str.contains("DAL") | df20_8['callsign'].str.contains('QTR')] 
df20_9f = df20_9[df20_9['callsign'].str.contains("DAL") | df20_9['callsign'].str.contains('QTR')] 

#Concatenate the filtered dataframes into a single dataframe
df_19 = pd.concat([df19_1f, df19_2f, df19_3f, df19_4f, df19_5f, df19_6f, df19_7f, df19_8f, df19_9f, df19_10f, df19_11f, df19_12f])
df_20 = pd.concat([df20_1f, df20_2f, df20_3f, df20_4f, df20_5f, df20_6f, df20_7f, df20_8f, df20_9f])
pd_complete1 = pd.concat([df_19, df_20])
#print(pd_complete)

# %%
#Filter irrelevant the concatenated dataframe to reduce file size and save as csv file
pd_complete_filt = pd_complete1.drop(['lastseen','altitude_1','altitude_2','day','number','icao24'],axis=1)
#print(pd_complete_filt)
pd_complete_filt.to_csv('/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/rawdata2.csv')

# %%
import pandas as pd
import glob, os

#This method can be used to read and filter multiple csv files, 
#concatenate them and then write the data to a new csv file
path = '/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/oversized_data'
all_files = glob.glob(os.path.join(path + "/flightlist_*.csv"))

#                                        Change these parameters for filter for different inputs
df_current = (pd.read_csv(f, usecols = ['callsign','typecode','origin','destination','firstseen']) for f in all_files)
dfy = pd.concat(df_current, ignore_index = True)

#Input value = "airline name" in "str.contains(value)" to extract data for whichever airline
dfy = dfy[dfy['callsign'].str.contains('ANA') | dfy['callsign'].str.contains('DAL')]

dfy.head()
# Out:
#     callsign typecode origin destination                  firstseen
# 94    ANA203     B789    NaN        EDDF  2020-07-31 15:53:07+00:00
# 126   DAL642     A319   KU42        KU42  2020-07-31 16:26:06+00:00
# 132   DAL934     B739   KATL        KU42  2020-07-31 16:35:18+00:00
# 157    ANA11     B77W   KORD         NaN  2020-07-31 17:13:41+00:00
# 211   DAL159      NaN   KDTW        RKSI  2020-07-31 18:06:13+00:00

# %%
#Ensure to change .csv name for each new csv extraction
dfy.to_csv('/Users/luke/Documents/UBCO/Data_301/Course_Project/course-project-solo_325/data/raw/rawdata3.csv')

# %%
# Out:
#    Unnamed: 0 callsign typecode origin destination                  firstseen
# 0          94   ANA203     B789    NaN        EDDF  2020-07-31 15:53:07+00:00
# 1         126   DAL642     A319   KU42        KU42  2020-07-31 16:26:06+00:00
# 2         132   DAL934     B739   KATL        KU42  2020-07-31 16:35:18+00:00
# 3         157    ANA11     B77W   KORD         NaN  2020-07-31 17:13:41+00:00
# 4         211   DAL159      NaN   KDTW        RKSI  2020-07-31 18:06:13+00:00
